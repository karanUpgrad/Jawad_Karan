# %% [markdown]
# ### Import Python Libraries:

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Ignore Warnings:

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Adjust views on Jupyter:

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
pd.set_option('display.expand_frame_repr', True)

# %%
#Importing the data
loan_data = pd.read_csv("loan/loan.csv")

# %%
#Check the first five rows
loan_data.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment grade sub_grade                 emp_title emp_length home_ownership  annual_inc verification_status issue_d  loan_status pymnt_plan                                                url                                               desc         purpose                 title zip_code addr_state    dti  delinq_2yrs earliest_cr_line  inq_last_6mths  mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  revol_bal revol_util  total_acc initial_list_status  out_prncp  out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt next_pymnt_d last_credit_pull_d  collections_12_mths_ex_med  mths_since_last_major_derog  policy_code application_type  annual_inc_joint  dti_joint  verification_status_joint  acc_now_delinq  tot_coll_amt  tot_cur_bal  open_acc_6m  open_il_6m  open_il_12m  \
# ...

# %%
#Dataframe Dimensions
print(loan_data.shape)

#Dataframe Size
print(loan_data.size)
# Out:
# (39717, 111)
# 4408587

# %%
#Datatypes of all the columns of the dataframe
loan_data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 111 columns):
#  #    Column                          Dtype
# ---   ------                          -----
#  0    id                              int64
#  1    member_id                       int64
#  2    loan_amnt                       int64
#  3    funded_amnt                     int64
#  4    funded_amnt_inv                 float64
#  5    term                            object
#  6    int_rate                        object
#  7    installment                     float64
#  8    grade                           object
#  9    sub_grade                       object
#  10   emp_title                       object
#  11   emp_length                      object
#  12   home_ownership                  object
#  13   annual_inc                      float64
#  14   verification_status             object
#  15   issue_d                         object
# ...

# %%
#Check the number of null values in the columns
loan_data.isnull().sum()
# Out:
# id                                    0
# member_id                             0
# loan_amnt                             0
# funded_amnt                           0
# funded_amnt_inv                       0
# term                                  0
# int_rate                              0
# installment                           0
# grade                                 0
# sub_grade                             0
# emp_title                          2459
# emp_length                         1075
# home_ownership                        0
# annual_inc                            0
# verification_status                   0
# issue_d                               0
# loan_status                           0
# pymnt_plan                            0
# url                                   0
# desc                              12940
# purpose                               0
# title                                11
# zip_code                              0
# ...

# %%
# Checking the numeric variables of the dataframes
loan_data.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  funded_amnt_inv   installment    annual_inc           dti   delinq_2yrs  inq_last_6mths  mths_since_last_delinq  mths_since_last_record      open_acc       pub_rec      revol_bal     total_acc     out_prncp  out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee    recoveries  collection_recovery_fee  last_pymnt_amnt  collections_12_mths_ex_med  mths_since_last_major_derog  policy_code  annual_inc_joint  dti_joint  verification_status_joint  acc_now_delinq  tot_coll_amt  tot_cur_bal  open_acc_6m  open_il_6m  open_il_12m  open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  total_cu_tl  inq_last_12m  acc_open_past_24mths  avg_cur_bal  bc_open_to_buy  bc_util  chargeoff_within_12_mths  delinq_amnt  mo_sin_old_il_acct  mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mort_acc  mths_since_recent_b
# ...

# %%
#All the Unwanted column assigned to Label.
unwanted_col = ['next_pymnt_d','mths_since_last_major_derog','annual_inc_joint','mths_since_last_record','mths_since_last_delinq','dti_joint','verification_status_joint','tot_coll_amt','tot_cur_bal','open_acc_6m','open_il_6m','open_il_12m','open_il_24m','mths_since_rcnt_il','total_bal_il','il_util','open_rv_12m','open_rv_24m','max_bal_bc','all_util','total_rev_hi_lim','inq_fi','total_cu_tl','inq_last_12m','acc_open_past_24mths','bc_open_to_buy','bc_util','mo_sin_old_il_acct','mo_sin_old_rev_tl_op','mo_sin_rcnt_rev_tl_op','mo_sin_rcnt_tl','mort_acc','mths_since_recent_bc','mths_since_recent_bc_dlq','mths_since_recent_inq','mths_since_recent_revol_delinq','num_accts_ever_120_pd','num_actv_bc_tl','num_actv_rev_tl','num_bc_sats','num_bc_tl','num_il_tl','num_op_rev_tl','num_rev_accts','num_rev_tl_bal_gt_0','num_sats','num_tl_120dpd_2m','num_tl_30dpd','num_tl_90g_dpd_24m','num_tl_op_past_12m','pct_tl_nvr_dlq','percent_bc_gt_75','tax_liens','tot_hi_cred_lim','total_bal_ex_mort','total_bc_limit','total_il_high_credit_limit']
len(unwanted_col)
# Out:
# 57

# %%
#Removing Un-wanted Column
flt_data = loan_data.drop(labels=unwanted_col, axis=1)

# %%
#Dataframe Dimensions
print(flt_data.shape)

#Dataframe Size
print(flt_data.size)
# Out:
# (39717, 54)
# 2144718

# %%
# Checking the numeric variables of the dataframes
flt_data.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  funded_amnt_inv   installment    annual_inc           dti   delinq_2yrs  inq_last_6mths      open_acc       pub_rec      revol_bal     total_acc     out_prncp  out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee    recoveries  collection_recovery_fee  last_pymnt_amnt  collections_12_mths_ex_med  policy_code  acc_now_delinq  avg_cur_bal  chargeoff_within_12_mths  delinq_amnt  pub_rec_bankruptcies
# ...

# %%
#Checking Data Information 'dtype' value
flt_data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 53 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          39717 non-null  int64
#  1   member_id                   39717 non-null  int64
#  2   loan_amnt                   39717 non-null  int64
#  3   funded_amnt                 39717 non-null  int64
#  4   funded_amnt_inv             39717 non-null  float64
#  5   term                        39717 non-null  object
#  6   int_rate                    39717 non-null  object
#  7   installment                 39717 non-null  float64
#  8   grade                       39717 non-null  object
#  9   sub_grade                   39717 non-null  object
#  10  emp_title                   37258 non-null  object
#  11  emp_length                  38642 non-null  object
#  12  home_ownership              39717 non-null  object
# ...

# %%
#Checking Null Values for data cleaning
flt_data.isnull().sum()
# Out:
# id                                0
# member_id                         0
# loan_amnt                         0
# funded_amnt                       0
# funded_amnt_inv                   0
# term                              0
# int_rate                          0
# installment                       0
# grade                             0
# sub_grade                         0
# emp_title                      2459
# emp_length                     1075
# home_ownership                    0
# annual_inc                        0
# verification_status               0
# issue_d                           0
# loan_status                       0
# pymnt_plan                        0
# url                               0
# desc                          12940
# purpose                           0
# title                            11
# zip_code                          0
# addr_state                        0
# dti                               0
# delinq_2yrs                       0
# ...

# %%
#Column "desc" NaN value replace with "Description Missing" strings.
flt_data['desc'] = flt_data['desc'].fillna('Description Missing')

# %%
#Checking Null value for desc column
print(flt_data['desc'].isnull().sum())
# Out:
# 0

# %%
flt_data['desc'].head()
# Out:
# 0      Borrower added on 12/22/11 > I need to upgra...
# 1      Borrower added on 12/22/11 > I plan to use t...
# 2                                  Description Missing
# 3      Borrower added on 12/21/11 > to pay for prop...
# 4      Borrower added on 12/21/11 > I plan on combi...
# Name: desc, dtype: object

# %%
flt_data.isnull().sum()
# Out:
# id                               0
# member_id                        0
# loan_amnt                        0
# funded_amnt                      0
# funded_amnt_inv                  0
# term                             0
# int_rate                         0
# installment                      0
# grade                            0
# sub_grade                        0
# emp_title                     2459
# emp_length                    1075
# home_ownership                   0
# annual_inc                       0
# verification_status              0
# issue_d                          0
# loan_status                      0
# pymnt_plan                       0
# url                              0
# desc                             0
# purpose                          0
# title                           11
# zip_code                         0
# addr_state                       0
# dti                              0
# delinq_2yrs                      0
# earliest_cr_line                 0
# ...

# %%
#Checking Data Information 'dtype' value for int_rate
flt_data[['int_rate']].info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   int_rate  39717 non-null  object
# dtypes: object(1)
# memory usage: 310.4+ KB

# %%
#Converting int_rate column into String First
flt_data.int_rate = flt_data.int_rate.apply(lambda x: str(x)[:-1])

# %%
#Converting int_rate column into Float
flt_data.int_rate = flt_data.int_rate.astype(float)

# %%
#Checking Data Information 'dtype' value for int_rate
flt_data[['int_rate']].info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   int_rate  39717 non-null  float64
# dtypes: float64(1)
# memory usage: 310.4 KB

# %%
#Checking the percentage is presented in the column
flt_data.int_rate.head()
# Out:
# 0    10.65
# 1    15.27
# 2    15.96
# 3    13.49
# 4    12.69
# Name: int_rate, dtype: float64

# %%
#Checking Data Information 'dtype' value for emp_length
flt_data[['emp_length']].info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   emp_length  38642 non-null  object
# dtypes: object(1)
# memory usage: 310.4+ KB

# %%
#Checking Null Value in the column 'emp_length'
flt_data['emp_length'].isnull().sum()
# Out:
# 1075

# %%
#Verify the counts of emp_length column
flt_data['emp_length'].value_counts()
# Out:
# 10+ years    8879
# < 1 year     4583
# 2 years      4388
# 3 years      4095
# 4 years      3436
# 5 years      3282
# 1 year       3240
# 6 years      2229
# 7 years      1773
# 8 years      1479
# 9 years      1258
# Name: emp_length, dtype: int64

# %%
#Removed String value and keep in INT
flt_data['emp_length'] = flt_data['emp_length'].str.extract('(\d+)', expand=False)

# %%
#Re-verify the counts of emp_length column
flt_data['emp_length'].value_counts()
# Out:
# 10    8879
# 1     7823
# 2     4388
# 3     4095
# 4     3436
# 5     3282
# 6     2229
# 7     1773
# 8     1479
# 9     1258
# Name: emp_length, dtype: int64

# %%
#Replace N/A row with number 4, as this is Median value which is taken from further analysis.
flt_data['emp_length'] = flt_data['emp_length'].fillna(4)

# %%
#Re-checking Null Value in the column 'emp_length'
flt_data['emp_length'].isnull().sum()
# Out:
# 0

# %%
flt_data.emp_length.describe()
# Out:
# count     39717
# unique       11
# top          10
# freq       8879
# Name: emp_length, dtype: object

# %%
#Converting Dtype of emp_length columbn to INT
flt_data['emp_length'] = flt_data.emp_length.astype(int)

# %%
flt_data[['emp_length']].info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   emp_length  39717 non-null  int32
# dtypes: int32(1)
# memory usage: 155.3 KB

# %%
#Checking the Mean value from emp_length
flt_data.emp_length.describe()
# Out:
# count    39717.000000
# mean         5.062492
# std          3.366562
# min          1.000000
# 25%          2.000000
# 50%          4.000000
# 75%          9.000000
# max         10.000000
# Name: emp_length, dtype: float64

# %%
#Checking the Median value from emp_length
flt_data.emp_length.median()
# Out:
# 4.0

# %%
plt.boxplot(flt_data.emp_length)
plt.show()

# %%
flt_data['loan_status'].head()
# Out:
# 0     Fully Paid
# 1    Charged Off
# 2     Fully Paid
# 3     Fully Paid
# 4        Current
# Name: loan_status, dtype: object

# %%
#Bar char for current Loan Status
flt_data.loan_status.value_counts(1).plot(kind='bar')
plt.show()

# %%
#Removing Current Loan users under "loan_status" column
flt_data = flt_data.drop(flt_data["loan_status"].loc[flt_data["loan_status"] == 'Current'].index)

# %%
#Now we have only 
flt_data.loan_status.value_counts(1).plot(kind='bar')
plt.show()

# %%
#Imbalance Analysis chart

imb = flt_data["loan_status"].value_counts().reset_index()
plt.figure(figsize=(10,4))
x= ['Repayer','Defaulter']
sns.barplot(x,"loan_status",data = imb,palette= ['b','r'])
plt.xlabel("Loan Status")
plt.ylabel("Count of Repayers & Defaulters")
plt.title("Imbalance Plotting")
plt.show()

# %%
#Checking Null Value in the column 'pub_rec_bankruptcies'
flt_data['pub_rec_bankruptcies'].isnull().sum()
# Out:
# 697

# %%
#Checking the Mean value from pub_rec_bankruptcies
flt_data.pub_rec_bankruptcies.describe()
# Out:
# count    37880.000000
# mean         0.043479
# std          0.204583
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          2.000000
# Name: pub_rec_bankruptcies, dtype: float64

# %%
#Checking the Mean value from pub_rec_bankruptcies
flt_data.pub_rec_bankruptcies.median()
# Out:
# 0.0

# %%
#Replace N/A row with number 0 as per the Median 
flt_data['pub_rec_bankruptcies'] = flt_data['pub_rec_bankruptcies'].fillna(0)

# %%
#Re-checking Null Value in the column 'pub_rec_bankruptcies'
flt_data['pub_rec_bankruptcies'].isnull().sum()
# Out:
# 0

# %%
plt.boxplot(flt_data.pub_rec_bankruptcies)
plt.show()

# %%
#Starting work on the Bivariate anysis 

#Checking Data Information 'dtype' value for term
flt_data[['term']].info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38577 entries, 0 to 39716
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   term    38577 non-null  object
# dtypes: object(1)
# memory usage: 602.8+ KB

# %%
#Checking for null values in term Column 

flt_data['term'].isnull().sum()
# Out:
# 0

# %%
#Verify the counts of term column
flt_data['term'].value_counts()
# Out:
#  36 months    29096
#  60 months     9481
# Name: term, dtype: int64

# %%
#Removed String value and keep in INT
flt_data['term'] = flt_data['term'].str.extract('(\d+)', expand=False)

# %%
#verifing if we have removed the string part of the term
flt_data['term'].describe
# Out:
# <bound method NDFrame.describe of 0        36
# 1        60
# 2        36
# 3        36
# 5        36
#          ..
# 39712    36
# 39713    36
# 39714    36
# 39715    36
# 39716    36
# Name: term, Length: 38577, dtype: object>

# %%
#since we only have two values we see the distribution
flt_data['term'].value_counts()
# Out:
# 36    29096
# 60     9481
# Name: term, dtype: int64

# %%
#Converting term column into int
flt_data.term = flt_data.term.astype(int)

# %%
flt_data['term'].describe()
# Out:
# count    38577.000000
# mean        41.898437
# std         10.333136
# min         36.000000
# 25%         36.000000
# 50%         36.000000
# 75%         36.000000
# max         60.000000
# Name: term, dtype: float64

# %%
flt_data.term.value_counts(1).plot(kind='pie')
plt.show()

# %%
#now pweforming bivariant analysis with Term and loan Status // this shows us that the loans that have 36 months as a term has more chances of getting fully paid 

sns.boxplot(x=flt_data['term'],y=flt_data['loan_status'])
# Out:
# <AxesSubplot:xlabel='term', ylabel='loan_status'>

# %%
#working with intrest rate, in the past we have removed the percentage sign 

flt_data['int_rate'].describe
# Out:
# <bound method NDFrame.describe of 0        10.65
# 1        15.27
# 2        15.96
# 3        13.49
# 5         7.90
#          ...
# 39712     8.07
# 39713    10.28
# 39714     8.07
# 39715     7.43
# 39716    13.75
# Name: int_rate, Length: 38577, dtype: float64>

# %%
#analysis of intrest rate and loan status // this shows that intrest rates below 11% ( approx) intrest rates have more fully paid status
#Below 

sns.boxplot(x ='int_rate', y = 'loan_status', data = flt_data)
# Out:
# <AxesSubplot:xlabel='int_rate', ylabel='loan_status'>

# %%
#working with intrest rate, in the past we have removed the string  

flt_data['emp_length'].describe
# Out:
# <bound method NDFrame.describe of 0        10
# 1         1
# 2        10
# 3        10
# 5         3
#          ..
# 39712     4
# 39713     3
# 39714     1
# 39715     1
# 39716     1
# Name: emp_length, Length: 38577, dtype: int32>

# %%
#analysis of employee lenght and loan status // this shows that although the median is the same for both the status, it is very evidant that  more people in the higher employement length may not pay back the loan
#the Q3 is higher for the charged off where employee lenght is between 8 to 10 // 
sns.boxplot(x ='emp_length', y = 'loan_status', data = flt_data)
# Out:
# <AxesSubplot:xlabel='emp_length', ylabel='loan_status'>

# %%
#analysis of DTI and loan status 
#the values are higher for chareged off where DTI is higher, this proves that if the ratio between loan amount and monthly income is high then there is a  slightly higher number ( verly little ) of people who charged off the loan 
# If the monthly income is lesser than the loan amount then there is 
sns.boxplot(x ='dti', y = 'loan_status', data = flt_data)
# Out:
# <AxesSubplot:xlabel='dti', ylabel='loan_status'>

# %%
##Analyzing the data between bankruptcies and loan status TO BE DROPPED 
#this shows the loan status of fully paid is much higher when there are no bankruptices

sns.catplot(x ='pub_rec_bankruptcies', y = 'loan_status', data = flt_data, kind="point")

# %%
#this proves that there is not much of correlation between intrest rates and installments 

corrMatrix = flt_data['int_rate'].corr(flt_data['installment'])

corrMatrix
# Out:
# 0.2772034121541835

# %%
# performing correlation analysis on the cleaned data 
small_Data = flt_data[['installment','pub_rec','open_acc','dti','int_rate','funded_amnt','emp_length']].copy()
corr = small_Data.corr()
corr.style.background_gradient(cmap='coolwarm')

#from the below analysis we can observe that the funded amount tends to increase the installments which is rightly done
#we also obsever as DTI does not have a correlation with factors such as installments and int_rate however this would be a recomendation to increase the installments as the DTI decreases to improve the chances to get back the loan
# Out:
# <style  type="text/css" >
# #T_d3649_row0_col0,#T_d3649_row1_col1,#T_d3649_row2_col2,#T_d3649_row3_col3,#T_d3649_row4_col4{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_d3649_row0_col1{
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }#T_d3649_row0_col2,#T_d3649_row4_col2{
#             background-color:  #7295f4;
#             color:  #000000;
#         }#T_d3649_row0_col3{
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }#T_d3649_row0_col4,#T_d3649_row4_col0{
#             background-color:  #c32e31;
#             color:  #f1f1f1;
#         }#T_d3649_row1_col0,#T_d3649_row1_col2,#T_d3649_row1_col3,#T_d3649_row1_col4,#T_d3649_row4_col1{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_d3649_row2_col0{
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }#T_d3649_row2_col1{
# ...

# %%
# Univariant we find that the median and mode of the data is always B2 hence majority of these loans in our data set are given to grade B and subgrade B2 
k = flt_data['sub_grade'].median
l = flt_data['sub_grade'].mode
print(k,l)
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.median of 0        B2
# 1        C4
# 2        C5
# 3        C1
# 5        A4
#          ..
# 39712    A4
# 39713    C1
# 39714    A4
# 39715    A2
# 39716    E2
# Name: sub_grade, Length: 38577, dtype: object> <bound method Series.mode of 0        B2
# 1        C4
# 2        C5
# 3        C1
# 5        A4
#          ..
# 39712    A4
# 39713    C1
# 39714    A4
# 39715    A2
# 39716    E2
# Name: sub_grade, Length: 38577, dtype: object>

# %%
#using subgrad we have found a count of individual subgrads which are paid and not paid 

flt_data.loan_status.groupby(by = [ flt_data['sub_grade'],flt_data['loan_status']]).count()
# Out:
# sub_grade  loan_status
# A1         Charged Off      30
#            Fully Paid     1109
# A2         Charged Off      74
#            Fully Paid     1434
# A3         Charged Off     103
#            Fully Paid     1707
# A4         Charged Off     178
#            Fully Paid     2695
# A5         Charged Off     217
#            Fully Paid     2498
# B1         Charged Off     171
#            Fully Paid     1626
# B2         Charged Off     228
#            Fully Paid     1773
# B3         Charged Off     341
#            Fully Paid     2484
# B4         Charged Off     329
#            Fully Paid     2108
# B5         Charged Off     356
#            Fully Paid     2259
# C1         Charged Off     336
#            Fully Paid     1719
# C2         Charged Off     321
#            Fully Paid     1610
# C3         Charged Off     270
#            Fully Paid     1218
# C4         Charged Off     212
#            Fully Paid      994
# C5         Charged Off     208
# ...

# %%
k = flt_data.loan_status.groupby(by = [ flt_data['sub_grade'],flt_data['loan_status']]).count()
k.describe()
# Out:
# count      70.000000
# mean      551.100000
# std       705.101496
# min        10.000000
# 25%        92.750000
# 50%       216.000000
# 75%       748.750000
# max      2695.000000
# Name: loan_status, dtype: float64

# %%
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(20)
k.plot(kind = 'barh')
#hence we can say the Maximum loans that got fully paid are from the sub category - A4 and the maximum that got charged off are from B5

# we also deduce that Sub_Grade B1 and B2 might be calculated in a wrong way, the reason to say this is because we find that the defaulters are increasing in this range and the fully paid loans are also dropping, we may need to make a preventive measrue such as higher colateral while adding loads to this sub grade
# Out:
# <AxesSubplot:ylabel='sub_grade,loan_status'>

# %%
print(flt_data['avg_cur_bal'].isnull().count())
# Out:
# 39717
